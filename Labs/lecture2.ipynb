# %% [markdown]
# # Lecture 2 - Matrices & Matrix Determinant

# %% [markdown]
# ## Vectors

# %%
# a row array
a = [ 1 2 3 4 pi ]
# Out:
# 1×5 Matrix{Float64}:
#  1.0  2.0  3.0  4.0  3.14159

# %%
# a col array
b = [ 1, 2, 3, 4, pi]
# Out:
# 5-element Vector{Float64}:
#  1.0
#  2.0
#  3.0
#  4.0
#  3.141592653589793

# %%
# a col array with semicolon
c = [ 1; 2; 3; 4; pi]
# Out:
# 5-element Vector{Float64}:
#  1.0
#  2.0
#  3.0
#  4.0
#  3.141592653589793

# %%
b == c
# Out:
# true

# %% [markdown]
# ## Matrices

# %%
# 3 x 2 matrix
A = [1 2; 3 4; 5 6]
# Out:
# 3×2 Matrix{Int64}:
#  1  2
#  3  4
#  5  6

# %%
# 2 x 3 matrix
A = [1.2 -2.6 11.7;
     3.1 11/7 0]
# Out:
# 2×3 Matrix{Float64}:
#  1.2  -2.6      11.7
#  3.1   1.57143   0.0

# %%
# another way to define matrix
A = [2 3 4 6
     5 6 7 8]
# Out:
# 2×4 Matrix{Int64}:
#  2  3  4  6
#  5  6  7  8

# %%
# define A and b for an eqn
A = [ 1 5 0; 3 -1 7; -1 0 2]
b = [4; 2; -5]
# Out:
# 3-element Vector{Int64}:
#   4
#   2
#  -5

# %% [markdown]
# ## Determinants

# %%
using Pkg
Pkg.add("LinearAlgebra")
using LinearAlgebra
# Out:
#    Resolving package versions...
#      Project No packages added to or removed from `~/.julia/environments/v1.12/Project.toml`
#     Manifest No packages added to or removed from `~/.julia/environments/v1.12/Manifest.toml`

# %%
A = [ 1 2 3; 4 5 6; 7 8 9];
det(A)
# Out:
# -9.516197353929915e-16

# %%
A = [1 1 2 0 0; 2 -1 1 0 0; 1 0 4 0 0; 0 0 2 1 -5; 0 -4 0 12 0]
det(A)
# Out:
# -540.0

# %%
A = [0 1 0 0 2; 0 -7 0 0 -14; -5 0 4 0 0; 1 2 3 4 5; 0 -4 0 12 0]
det(A)
# Out:
# -1.7719159473017498e-13
